# %% [markdown]
# ## My first Neural Network - Perceptron
#
# Here I present my first neural network, a single-layer 2 classes perceptron classifier with simple two-dimensional custom data just to evaluate the algorithm.

# %%
import numpy as np
from p2d2c import Perceptron2d2c as Perceptron
import matplotlib.pyplot as plt

# %% [markdown]
# A simple set of two-dimensional labeled training data is used in this example. We have two classes, +1 and -1.

# %%
# train data
data = {}
data["dim1"] = [0.9,2,2,1.1,1,1.5]
data["dim2"] = [0.1,0.8,0.9,0.2,0.1,0.2]
data["class"] = [-1,1,1,-1,-1,1]

# %% [markdown]
# Now, we define our Perceptron and train it with the above defined data. We have to find a line that separates the training data according to its class. If this cannot be done (data cannot be divided with a line) the algorithm will minmize the number of errors in training data classification when it hits the maximum number of iterations (since it will not converge).

# %%
# train perceptron
nn = Perceptron(ploter=True) 
M = len(data["class"])
x = np.zeros((M,3))
for i in range(M):
    x[i][0] = data["dim1"][i]
    x[i][1] = data["dim2"][i]
    x[i][2] = data["class"][i]
nn.train(x)          
# plot results
# nn.plot(x,'final')
# Out:
# w =  [ 0.59  0.25]
# w0 =  -0.8
# it =  26

# %% [markdown]
# Now we can test a point to evaluate the accuracy of the classifier.

# %%
# test perceptron
testData = np.asarray([1.2,0.4])
clas = nn.evaluate(testData)
print("testData is of class ",clas)
plt.plot(testData[0],testData[1],'.b')

# plot results
nn.plot(x,'test')
# Out:
# testData is of class  1

# %% [markdown]
# This is the Perceptron class:

# %%
import numpy as np 
import random
import matplotlib.pyplot as plt 

class Perceptron2d2c:
    # init preceptron
    def __init__(self,a = 0.1,b = 0.1,itMax = 100, ploter=False):
        # parameters
        self.a = a
        self.b = b
        self.itMax = itMax
        self.ploter = ploter
        # init weights
        self.w = np.zeros(2)    
        self.w0 = 0.
        # 2 classes (+1, -1)
        self.c = np.zeros(2)
    # train perceptron
    def train(self,x):
        it = 0
        # extract labels
        self.c = x[:,2]
        x = x[:,0:2]
        # random acces to data
        arr = list(range(len(x)))
        random.shuffle(arr)        
        while True:
            error = 0.
            it += 1
            for i in arr:
                g = self.c[i]*(np.dot(self.w,x[i]) + self.w0)
                if g < self.b:
                    self.w += self.a*self.c[i]*x[i]
                    self.w0 += self.a*self.c[i]
                    error += 1
            if self.ploter:
                self.plot(x,tit="iteration "+str(it))
            if error == 0 or it >= self.itMax:
                break;
        print("w = ",self.w)
        print("w0 = ",self.w0)
        print("it = ",it)
        if it == self.itMax:            
            print("Not converged")
    # evaluate
    def evaluate(self,test):
        g = (np.dot(self.w,test) + self.w0)
        if g > 0:
            return 1
        else:
            return -1    
    # plot 
    def plot(self,x,tit=''):
        plt.plot(
            [j for i, j in enumerate(x[:,0]) if self.c[i] == 1],
            [j for i, j in enumerate(x[:,1]) if self.c[i] == 1],
            '.g'
        )
        plt.plot(
            [j for i, j in enumerate(x[:,0]) if self.c[i] == -1],
            [j for i, j in enumerate(x[:,1]) if self.c[i] == -1],
            '.r'
        )
        xp = np.arange(1,2,step=0.1)
        yp = -(xp*self.w[0] + self.w0)/self.w[1]
        plt.plot(xp,yp,'k')
        plt.title(tit)
        plt.show()

# %% [markdown]
# ## Propsed tasks
#
# - Try with a train data set that cannot be divided with a line, for example set point [0.9,0.1] to class 1. The algorithm will not converge without training errors (this is why we need a maxium number of iterations stop criteria), but the perceptron will be able to classify nevertheless.
# - The optimal parameters of the perceptron (a, b) will depend on the data and must be adjusted (it will affect convergence).

# %% [markdown]
# ## Author
#
# Juan Sensio - juansensio03@gmail.com
