# %% [markdown]
# ## My first neural network - Single layer Perceptron
#
# This is my first neural network, a single-layer perceptron classifier with simple multi-dimensional custom data just to evaluate the algorithm.

# %%
import numpy as np 
from perceptron import Perceptron
from plot import plot

# %% [markdown]
# Let's try a two-dimensional, two-classes case. We have to find a line that separates the training data according to its class.

# %%
# train data
M, D, C = 6, 2, 2
data = np.zeros((M,D+1))  # D + label
# last element is the label
data[0] = [0.9, 0.1, 0]
data[1] = [1.9, 0.8, 1]
data[2] = [2, 0.9, 1]
data[3] = [1 ,0.2, 0]
data[4] = [1.2, 0.1, 1]
data[5] = [1.6, 0.6, 1]
# train perceptron
nn = Perceptron(D,C)     
nn.train(data)
# Out:
# w =  [[-0.71 -0.2 ]
#  [ 0.71  0.2 ]]
# w0 =  [ 0.8 -0.8]
# it =  40

# %%
# test perceptron
testData = np.asarray([1.4, 0.3])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  1

# %%
# test perceptron
testData = np.asarray([1., -0.5])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  0

# %% [markdown]
# Now, with more classes.

# %%
# train data
M, D, C = 6, 2, 3
data = np.zeros((M,D+1))  # D + label
data[0] = [0.9, 0.1, 0]
data[1] = [1.9, 0.8, 2]
data[2] = [2, 0.9, 2]
data[3] = [1 ,0.2, 0]
data[4] = [1.2, 0.1, 1]
data[5] = [1.6, 0.6, 1]
# train perceptron
nn = Perceptron(D,C)     
nn.train(data)
# Out:
# w =  [[-2.11 -0.36]
#  [-0.59 -1.46]
#  [-0.54  1.19]]
# w0 =  [ 0.8 -0.8 -2.6]
# it =  106

# %%
# test perceptron
testData = np.asarray([1., -0.5])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  1

# %%
# test perceptron
testData = np.asarray([1., 0.5])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  0

# %%
# test perceptron
testData = np.asarray([1.8, 1])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  2

# %% [markdown]
# Let's try with three-dimensional, two-classes data. Now, the data is separated with a plane.

# %%
# train data
M, D, C = 6, 3, 2
data = np.zeros((M,D+1))  # D + label
data[0] = [0.9, 0.1, 0, 0]
data[1] = [1.9, 0.8, 0.9, 1]
data[2] = [2, 0.9, 0.8, 1]
data[3] = [1 ,0.2, 0.1, 0]
data[4] = [1.2, 0.1, 0.2, 0]
data[5] = [1.6, 0.6, 0.6, 1]
# train perceptron
nn = Perceptron(D,C)     
nn.train(data)
# Out:
# w =  [[-0.05 -0.23 -0.28]
#  [ 0.05  0.23  0.28]]
# w0 =  [ 0.3 -0.3]
# it =  4

# %%
# test perceptron
testData = np.asarray([1.2, 0.3, 0.2])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  0

# %%
# test perceptron
testData = np.asarray([1.2, 0.3, 0.8])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  1

# %% [markdown]
# And now, with 3 classes.

# %%
# train data
M, D, C = 6, 3, 3
data = np.zeros((M,D+1))  # D + label
data[0] = [0.9, 0.1, 0, 0]
data[1] = [1.9, 0.8, 0.9, 2]
data[2] = [2, 0.9, 0.8, 2]
data[3] = [1 ,0.2, 0.1, 0]
data[4] = [1.2, 0.1, 0.4, 1]
data[5] = [1.6, 0.6, 0.6, 1]
# train perceptron
nn = Perceptron(D,C)     
nn.train(data)
# Out:
# w =  [[-1.42 -0.22 -1.55]
#  [-0.98 -1.02  0.03]
#  [-1.07  0.49  0.31]]
# w0 =  [-0.1 -0.7 -1.8]
# it =  35

# %%
# test perceptron
testData = np.asarray([1.2, 0.8, 1.5])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  2

# %%
# test perceptron
testData = np.asarray([1.2, 0.3, -0.5])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  0

# %%
# test perceptron
testData = np.asarray([1.2, 0.3, 0.5])
print("testData is of class ", nn.evaluate(testData))
plot(data,'test',testData,D,C,nn.w,nn.w0)
# Out:
# testData is of class  1

# %% [markdown]
# Finally, multi-dimensional, multi-class data. The Perceptron will compute hyperplanes that separate the data according to its class.

# %%
# train data
M, D, C = 6, 5, 3
data = np.zeros((M,D+1))  # D + label
data[0] = [0.9, 0.1, 0, 0.5, 0, 0]
data[1] = [1.9, 0.8, 0.9, 0., 0, 2]
data[2] = [2, 0.9, 0.8, 0.1, 0, 2]
data[3] = [1 ,0.2, 0.1, 0.6, 1, 0]
data[4] = [1.2, 0.1, 0.2, 0.7, 1, 1]
data[5] = [1.6, 0.6, 0.6, 0.2, 1, 1]
# train perceptron
nn = Perceptron(D,C)     
nn.train(data)
# Out:
# w =  [[-0.74 -0.12 -0.71  0.22 -0.1 ]
#  [-0.08 -0.24  0.29 -0.18  0.3 ]
#  [-0.22  0.05  0.14 -0.31 -0.6 ]]
# w0 =  [ 0.3 -0.7 -0.4]
# it =  28

# %%
# test perceptron
testData = np.asarray([1.2, 0.3, 0.2, 0., 1])
print("testData is of class ", nn.evaluate(testData))
# Out:
# testData is of class  1

# %% [markdown]
# ## Propsed tasks
#
# - Try with a train data set that cannot be divided with a hyperplane (line or plane), for example set first point to class 1. The algorithm will not converge without training errors (this is why we need a maxium number of iterations stop criteria), but the perceptron will be able to classify nevertheless.
# - The optimal parameters of the perceptron (a, b) will depend on the data and must be adjusted (it will affect convergence).

# %% [markdown]
# ## Author
#
# Juan Sensio - juansensio03@gmail.com
